# %%
import pandas as pd

# Leer los dos archivos JSON
ips_1 = pd.read_json(r"C:\Users\SERGIO\Downloads\sda proy\sda proy\ASN\REPUTATION\info_ips_repu_2013_p1.json")
ips_2 = pd.read_json(r"C:\Users\SERGIO\Downloads\sda proy\sda proy\ASN\REPUTATION\info_ips_repu_2013_p2.json")

# Combinar los DataFrames
merged_dataframe = pd.concat([ips_1, ips_2], ignore_index=True)

# Guardar el DataFrame combinado en un nuevo archivo JSON
merged_dataframe.to_json("ips_datos_repu_2013.json", orient="records", lines=True)

print("Los dos archivos JSON han sido combinados y guardados como 'merged_output.json'.")
# Out:
# Los dos archivos JSON han sido combinados y guardados como 'merged_output.json'.
